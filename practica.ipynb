# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# Definir un dataframe para llamar el dataset
df = pd.read_csv("./data/disney_movies.csv")

#Ejecutar
df
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                          Pinocchio   1940-02-09  Adventure           G
# 2                           Fantasia   1940-11-13    Musical           G
# 3                  Song of the South   1946-11-12  Adventure           G
# 4                         Cinderella   1950-02-15      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                   Queen of Katwe   2016-09-23      Drama          PG
# 576                   Doctor Strange   2016-11-04  Adventure       PG-13
# 577                            Moana   2016-11-23  Adventure          PG
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# ...

# %%
#Ejecutar por cantidad de filas
df.head(5)
# Out:
#                        movie_title release_date      genre mpaa_rating  \
# 0  Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                        Pinocchio   1940-02-09  Adventure           G
# 2                         Fantasia   1940-11-13    Musical           G
# 3                Song of the South   1946-11-12  Adventure           G
# 4                       Cinderella   1950-02-15      Drama           G
#
#    total_gross  inflation_adjusted_gross
# 0    184925485                5228953251
# 1     84300000                2188229052
# 2     83320000                2187090808
# 3     65000000                1078510579
# 4     85000000                 920608730

# %%
print(df["movie_title"][:10])
# Out:
# 0    Snow White and the Seven Dwarfs
# 1                          Pinocchio
# 2                           Fantasia
# 3                  Song of the South
# 4                         Cinderella
# 5       20,000 Leagues Under the Sea
# 6                 Lady and the Tramp
# 7                    Sleeping Beauty
# 8                     101 Dalmatians
# 9        The Absent Minded Professor
# Name: movie_title, dtype: object

# %%
#Seleccionar los de genero musical
musical = df[ df["genre"] == "Musical"]
musical.head(10)
# Out:
#                          movie_title release_date    genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21  Musical           G
# 2                           Fantasia   1940-11-13  Musical           G
# 10                  Babes in Toyland   1961-12-14  Musical           G
# 13                   The Jungle Book   1967-10-18  Musical   Not Rated
# 15                    The Aristocats   1970-04-24  Musical           G
# 17          Bedknobs and Broomsticks   1971-10-07  Musical         NaN
# 114             Beauty and the Beast   1991-11-13  Musical           G
# 142                       Swing Kids   1993-03-05  Musical       PG-13
# 161   The Nightmare Before Christmas   1993-10-13  Musical          PG
# 254                            Evita   1996-12-25  Musical          PG
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# 2       83320000                2187090808
# 10      10218316                 124841160
# ...

# %%
#Ordenar por fecha
musical = musical.set_index("release_date")
musical = musical.sort_values(by="release_date")

musical.head(10)
# Out:
#                                   movie_title    genre mpaa_rating  \
# release_date
# 1937-12-21    Snow White and the Seven Dwarfs  Musical           G
# 1940-11-13                           Fantasia  Musical           G
# 1961-12-14                   Babes in Toyland  Musical           G
# 1967-10-18                    The Jungle Book  Musical   Not Rated
# 1970-04-24                     The Aristocats  Musical           G
# 1971-10-07           Bedknobs and Broomsticks  Musical         NaN
# 1991-11-13               Beauty and the Beast  Musical           G
# 1993-03-05                         Swing Kids  Musical       PG-13
# 1993-10-13     The Nightmare Before Christmas  Musical          PG
# 1996-12-25                              Evita  Musical          PG
#
#               total_gross  inflation_adjusted_gross
# release_date
# 1937-12-21      184925485                5228953251
# 1940-11-13       83320000                2187090808
# ...

# %%
#muestras máximas
MAX_SAMPLES = 100

taquilla = musical["total_gross"][: MAX_SAMPLES]
plt.plot(taquilla, label="taquilla bruta")
#plt.show()

# %%
plt.plot(taquilla, label="taquilla bruta")
plt.title("Taquilla de las películas vs tiempo")
plt.xlabel("Fecha")
plt.ylabel("Taquilla en $")
plt.legend()
#plt.show()

# %%
plt.plot(taquilla, label="taquilla bruta")
plt.title("Taquilla de las películas vs tiempo")
plt.xlabel("Fecha")
plt.xticks(rotation=90)
plt.ylabel("Taquilla en $")
plt.legend()

# %%
#
inflacion = musical["inflation_adjusted_gross"][: MAX_SAMPLES]
plt.plot(inflacion, label="inflación ajustada")
#plt.show()

# %%
plt.plot(inflacion, label="inflación ajustada")
plt.title("inflación ajustada de las películas vs tiempo")
plt.xlabel("Fecha")
plt.xticks(rotation=90)
plt.ylabel("inflación ajustada en $")
plt.legend()

# %% [markdown]
# # Limpieza de Datos / Data Cleaning

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# Definir un dataframe para llamar el dataset
df = pd.read_csv("./data/disney_movies.csv")

#Ejecutar
df
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                          Pinocchio   1940-02-09  Adventure           G
# 2                           Fantasia   1940-11-13    Musical           G
# 3                  Song of the South   1946-11-12  Adventure           G
# 4                         Cinderella   1950-02-15      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                   Queen of Katwe   2016-09-23      Drama          PG
# 576                   Doctor Strange   2016-11-04  Adventure       PG-13
# 577                            Moana   2016-11-23  Adventure          PG
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# ...

# %% [markdown]
# ## 1. Detección de Datos Nulos

# %%
#Para detectar nulos / Los que aparece como TRUE son valores nulos
df.isnull().head(10)


#Realiza lo contario
#datos.notnull()
# Out:
#    movie_title  release_date  genre  mpaa_rating  total_gross  \
# 0        False         False  False        False        False
# 1        False         False  False        False        False
# 2        False         False  False        False        False
# 3        False         False  False        False        False
# 4        False         False  False        False        False
# 5        False         False  False         True        False
# 6        False         False  False        False        False
# 7        False         False  False         True        False
# 8        False         False  False        False        False
# 9        False         False  False         True        False
#
#    inflation_adjusted_gross
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# 5                     False
# 6                     False
# 7                     False
# ...

# %%
# Eliminar filas con datos nulos / La desventaja es que se eliminan hasta las que tienen solo 1
# df.dropna()

# %%
# Rellena los datos nulos con un valor predeterminado
# df.fillna() ---- Ejemplo: df.fillna(value=100)

# %%
# Rellena los datos nulos con el valor de la fila siguiente
# df.fillna(method="bfill")

# %%
# Detectar los Outliers de forma visual
# print(df.describe)

# %%
# Uso del histograma para una mirada rápida de los datos / Si existe una disparidad muy notoria en la gráfica, puede deberse a un outlier.
# df.hist()

# %%
# En el DATASET DISNEY MOVIES solo la columna mpaa_rating contiene valores nulos
#significados de los valores: El sistema de calificaciones de la Motion Picture Association
# G: General Audience. Se admiten todas las edades
# PG: Parental Guidance Suggested: Algunos contenidos pueden no ser apropiados para niños
# PG-13: Parents Strongly Cautioned: Algunos contenidos pueden no ser apropiados para niños -13
# R: Restricted: -17 requieren acompañamiento de un adulto

# %%
# Mostrar Cantidad de filas y columnas
df.shape
# Out:
# (579, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579 entries, 0 to 578
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   movie_title               579 non-null    object
#  1   release_date              579 non-null    object
#  2   genre                     562 non-null    object
#  3   mpaa_rating               523 non-null    object
#  4   total_gross               579 non-null    int64
#  5   inflation_adjusted_gross  579 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 27.3+ KB

# %%
# Se puede usar isna() o isnull()
df.isna().head(10)
# Out:
#    movie_title  release_date  genre  mpaa_rating  total_gross  \
# 0        False         False  False        False        False
# 1        False         False  False        False        False
# 2        False         False  False        False        False
# 3        False         False  False        False        False
# 4        False         False  False        False        False
# 5        False         False  False         True        False
# 6        False         False  False        False        False
# 7        False         False  False         True        False
# 8        False         False  False        False        False
# 9        False         False  False         True        False
#
#    inflation_adjusted_gross
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# 5                     False
# 6                     False
# 7                     False
# ...

# %%
df.mpaa_rating = df.mpaa_rating.fillna(method='bfill')
df.head(10)
# Out:
#                        movie_title release_date      genre mpaa_rating  \
# 0  Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                        Pinocchio   1940-02-09  Adventure           G
# 2                         Fantasia   1940-11-13    Musical           G
# 3                Song of the South   1946-11-12  Adventure           G
# 4                       Cinderella   1950-02-15      Drama           G
# 5     20,000 Leagues Under the Sea   1954-12-23  Adventure           G
# 6               Lady and the Tramp   1955-06-22      Drama           G
# 7                  Sleeping Beauty   1959-01-29      Drama           G
# 8                   101 Dalmatians   1961-01-25     Comedy           G
# 9      The Absent Minded Professor   1961-03-16     Comedy           G
#
#    total_gross  inflation_adjusted_gross
# 0    184925485                5228953251
# 1     84300000                2188229052
# 2     83320000                2187090808
# ...

# %%
df.genre = df.genre.fillna(method='bfill')
df.head(10)
# Out:
#                        movie_title release_date      genre mpaa_rating  \
# 0  Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                        Pinocchio   1940-02-09  Adventure           G
# 2                         Fantasia   1940-11-13    Musical           G
# 3                Song of the South   1946-11-12  Adventure           G
# 4                       Cinderella   1950-02-15      Drama           G
# 5     20,000 Leagues Under the Sea   1954-12-23  Adventure           G
# 6               Lady and the Tramp   1955-06-22      Drama           G
# 7                  Sleeping Beauty   1959-01-29      Drama           G
# 8                   101 Dalmatians   1961-01-25     Comedy           G
# 9      The Absent Minded Professor   1961-03-16     Comedy           G
#
#    total_gross  inflation_adjusted_gross
# 0    184925485                5228953251
# 1     84300000                2188229052
# 2     83320000                2187090808
# ...

# %%
#Seleccionar los de genero musical
df[ df["genre"] == "Musical"]
# Rellena los datos nulos con el valor de la fila siguiente
# df.fillna(method="bfill")

# %%
#Seleccionar los de genero musical y rellenar
df.fillna(method="bfill").head(10)

# %%
df.head(10)

# %%
# Reemplazar los datos NOT RATED por una categoría mpaa
df['mpaa_rating'] = df['mpaa_rating'].replace(['Not Rated'], ['G'])
df[ df["genre"] == "Musical"]
